# %%
import pandas as pd
import sqlite3
import os

# %%
db = sqlite3.connect("Monarchs1995.db")

# %%
df = pd.read_csv("1995 Season Summary.csv")

        #convert pandas to SQL table
df.to_sql("monarchs1995", db, if_exists="replace")

os.getcwd()
# Out:
# 'C:\\Users\\Arink\\Desktop\\github\\CodeLou\\Monarchs\\Data'

# %%
schema = pd.read_sql('SELECT * FROM sqlite_master ORDER by name', db)
schema
# Out:
#     type                   name      tbl_name  rootpage  \
# 0  index  ix_monarchs1995_index  monarchs1995         4
# 1  table           monarchs1995  monarchs1995         2
#
#                                                  sql
# 0  CREATE INDEX "ix_monarchs1995_index"ON "monarc...
# 1  CREATE TABLE "monarchs1995" (\n"index" INTEGER...

# %% [markdown]
# ## Checking DataType

# %%
data_type = pd.read_sql('SELECT * FROM PRAGMA_TABLE_INFO("monarchs1995")', db)
data_type
# Out:
#     cid             name     type  notnull dflt_value  pk
# 0     0            index  INTEGER        0       None   0
# 1     1          Tag No.     TEXT        0       None   0
# 2     2           Tagger     TEXT        0       None   0
# 3     3         Mon. Sex     TEXT        0       None   0
# 4     4     Where Tagged     TEXT        0       None   0
# 5     5      Date Tagged     TEXT        0       None   0
# 6     6   Date Recovered     TEXT        0       None   0
# 7     7  Where Recovered     TEXT        0       None   0
# 8     8         Observer     TEXT        0       None   0
# 9     9         Interval     TEXT        0       None   0
# 10   10            Miles     REAL        0       None   0

# %% [markdown]
# ### Drop tagger and reporter identification

# %%
df.drop(["Tagger", "Mon. Sex", "Observer", "Interval"], axis = 1, inplace = True)
df
# Out:
#    Tag No.             Where Tagged   Date Tagged  Date Recovered  \
# 0   AU 646               Keene,  NY        19-Sep          Feb-96
# 1   BW 003        Huntingtown, \nMD        14-Sep       Dec\n1995
# 2   AN 008        West St Paul,  MN         4-Sep           1-Mar
# 3   AG 802             Sheldon,  IA           NaN       Mar\n1996
# 4   CU 878              Wamego,  KS        23-Sep          Mar-96
# 5   BP 359                Hays,  KS        18-Sep          24-Feb
# 6   BP 652                Hays,  KS        18-Sep       Mar\n1996
# 7   BO 299          Hutchinson,  KS         1-Oct          15-Jan
# 8   CM 355          Berryville,  AR        25-Sep          30-Dec
# 9   CJ 954             Andover,  KS        24-Sep       Mar\n1996
# 10  AS 887             Wichita,  KS        23-Sep       Mar\n1996
# 11  AM 907           Hillsboro,  KS        27-Sep          19-Oct
# 12  BH 331  Cleveland\nHeights,  OH           NaN           3-Oct
# 13  AS 610           Hillsboro,  KS        20-Sep           4-Oct
# 14  AU 652               Keene,  NY        29-Sep          12-Oct
# 15  CG 235            Lawrence,  KS        18-Sep          29-Sep
# 16  AO 022            Sunapee,  NH            NaN          22-Sep
# 17  CM 577           Flourtown,  PA        12-Oct          27-Oct
# 18  BO 125              Benton,  KS        22-Sep          23-Sep
# 19  CK 683              Salina,  KS        20-Sep          25-Sep
# 20  CB 809              Groton,  MA        13-Oct          22-Oct
# 21  BW 716          Tabernacle,  NJ        23-Sep          24-Sep
# 22  AQ 178           Maquoketa,  IA         9-Sep          16-Sep
# 23  AS 039              Wamego,  KS         3-Sep          18-Sep
# 24  204 AD          Moundridge,  KS        17-Sep          27-Sep
# 25  AF 384         Minnetonka, \nMN           NaN          19-Oct
# 26   CP694           Sunnyvale,  TX           NaN     7 May\n1996
# 27  CB 662          Middletown,  NJ           NaN  before\n14 Oct
# 28  BO 329              Topeka,  KS        23-Sep          26-Sep
# 29  BE 018        Cape May Pt, \nNJ        28-Sep           2-Oct
# 30  AX 734          Cape May Pt, NJ        24-Sep           1-Oct
# 31  BE 146          Cape May Pt, NJ        30-Sep           1-Oct
# 32  AR 216            Lawrence,  KS        26-Sep             NaN
# 33   BA402      Point Lookout, \nMD        28-Sep           1-Oct
# 34  BR 711           Lewisburg,  WV        13-Sep           6-Sep
# 35  AB 902         Mifflinburg,  PA         8-Sep           9-Sep
# 36  CJ 946             Andover,  KS        24-Sep          25-Sep
# 37  AQ 103           St. Cloud,  MN           NaN          24-Sep
# 38  BN 789              Salina,  KS        17-Sep          20-Sep
# 39  CH 262               Austin, TX        21-Sep          28-Sep
# 40  CW 347              Wamego,  KS        20-Sep          20-Sep
# 41  AQ 443        Clintonville,  WI        14-Sep          15-Sep
# 42  AR 833             Wichita,  KS           NaN          27-Sep
# 43  CI 706              Olathe,  KS        24-Sep          29-Sep
# 44   CA512              Wamego,  KS         7-Sep           7-Sep
# 45  BD 004          Stillwater,  MN         2-Oct          16-Oct
# 46  MJ 356     Corpus Christi, \nTX           NaN          11-Oct
# 47  CN 555        Gaithersburg,  MD           NaN          22-Oct
# 48  CQ 903              Austin,  TX  10 May\n1996     12May\n1996
# 49  AK 132                      NaN           NaN          15-Oct
# 50  393 KG                      NaN           NaN          18-Aug
# 51  AU 742                      NaN           NaN           3-Oct
#
#                          Where Recovered   Miles
# 0            El Rosario colony, \nMexico  2580.0
# 1            El Rosario\ncolony,  Mexico  2285.0
# 2            El Rosario\ncolony,  Mexico  1990.0
# 3                       Chinqua,  Mexico  1820.0
# 4                       Chinqua,  Mexico  1555.0
# 5                Sierra Chinqua,  Mexico  1510.0
# 6                      Chinqua, \nMexico  1510.0
# 7       Herrada or Las Palomas, \nMexico  1500.0
# 8             El Rosario colony,  Mexico  1445.0
# 9                       Chinqua,  Mexico  1445.0
# 10                      Chinqua,  Mexico  1440.0
# 11                  Carrizo Springs,  TX   694.0
# 12                     Rock\nIsland,  IL   465.0
# 13                          Waurika,  OK   290.0
# 14                      Westbrook e,  CT   215.0
# 15                    Arkansas City,  KS   162.0
# 16                 Wappinger Falls,  NY:   152.0
# 17                      Roxboroug h,  PA   115.0
# 18                        El Dorado,  KS    78.0
# 19                            Lyons,  KS    46.0
# 20                       Worcester, \nMA    27.0
# 21  Lower South\n.Hampton Township, \nPA    26.0
# 22     Bellevue State Park Bellevue,  IA    17.0
# 23                        Manhattan,  KS    15.0
# 24                           Canton,  KS    14.0
# 25                    Minneapol\nis,  MN    11.0
# 26                          Garland,  TX     8.0
# 27                         Keansburg, NJ     3.0
# 28                            Topeka, KS     2.0
# 29                     Cape May\nPt,  NJ     0.0
# 30                          Cape May, NJ     0.0
# 31                          Cape May, NJ     0.0
# 32                        Lawrence, \nKS     0.0
# 33                           Ridge, \nMD     0.0
# 34                         Lewisburg, WV     0.0
# 35                   Mifflin-\nburg,  PA     0.0
# 36                          Andover,  KS     0.0
# 37                        St Cloud, \nMN     0.0
# 38                           Salina,  KS     0.0
# 39                            Austin, TX     0.0
# 40                           Wamego,  KS     0.0
# 41                   Clinton- ville,  WI     0.0
# 42                          Wichita,  KS     0.0
# 43                            Olathe, KS     0.0
# 44                            Wamego, KS     0.0
# 45                      Stillwater, \nMN     0.0
# 46                   Corpus\nChristi, TX     0.0
# 47                   Gaithers- burg,  MD     0.0
# 48                           Austin,  TX     0.0
# 49                          Oakdale,  MN     NaN
# 50         20 miles W of Iowa\nCity,  IA     NaN
# 51                        Brookline,  NH     NaN

# %% [markdown]
# ### Rename columns to match other years

# %%
df.rename(columns={'Date Tagged': 'Tag Date', 'Date Recovered': 'Report Date'}, inplace=True)

# %% [markdown]
# ### Split & rename combined columns in Tagged category

# %%
df.loc[df['Where Tagged'].str.contains("\n", na=False), "Where Tagged"] = df.loc[df['Where Tagged'].str.contains("\n", na=False), "Where Tagged"].str.replace("\n", " ")
df2 = df['Where Tagged'].str.split(', ', expand=True, n=1)
df2.columns = ['tag_city', 'Tag State']
df2['Tag State'] = df2['Tag State'].str.strip()
df2
# Out:
#              tag_city Tag State
# 0               Keene        NY
# 1         Huntingtown        MD
# 2        West St Paul        MN
# 3             Sheldon        IA
# 4              Wamego        KS
# 5                Hays        KS
# 6                Hays        KS
# 7          Hutchinson        KS
# 8          Berryville        AR
# 9             Andover        KS
# 10            Wichita        KS
# 11          Hillsboro        KS
# 12  Cleveland Heights        OH
# 13          Hillsboro        KS
# 14              Keene        NY
# 15           Lawrence        KS
# 16            Sunapee        NH
# 17          Flourtown        PA
# 18             Benton        KS
# 19             Salina        KS
# 20             Groton        MA
# 21         Tabernacle        NJ
# 22          Maquoketa        IA
# 23             Wamego        KS
# 24         Moundridge        KS
# 25         Minnetonka        MN
# 26          Sunnyvale        TX
# 27         Middletown        NJ
# 28             Topeka        KS
# 29        Cape May Pt        NJ
# 30        Cape May Pt        NJ
# 31        Cape May Pt        NJ
# 32           Lawrence        KS
# 33      Point Lookout        MD
# 34          Lewisburg        WV
# 35        Mifflinburg        PA
# 36            Andover        KS
# 37          St. Cloud        MN
# 38             Salina        KS
# 39             Austin        TX
# 40             Wamego        KS
# 41       Clintonville        WI
# 42            Wichita        KS
# 43             Olathe        KS
# 44             Wamego        KS
# 45         Stillwater        MN
# 46     Corpus Christi        TX
# 47       Gaithersburg        MD
# 48             Austin        TX
# 49                NaN       NaN
# 50                NaN       NaN
# 51                NaN       NaN

# %% [markdown]
# ### Split & Rename combined columns in Reported category

# %%
df.loc[df['Where Recovered'].str.contains("\n", na=False), "Where Recovered"] = df.loc[df['Where Recovered'].str.contains("\n", na=False), "Where Recovered"].str.replace("\n", " ")
df3 = df['Where Recovered'].str.split(', ', expand=True, n=1)
df3.columns = ['report_city', 'Report State']
df3['Report State'] = df3['Report State'].str.strip()
df3.loc[df3['Report State'] == 'Mexico', 'Report State'] = 'Michoacán'
df3
# Out:
#                       report_city Report State
# 0               El Rosario colony    Michoacán
# 1               El Rosario colony    Michoacán
# 2               El Rosario colony    Michoacán
# 3                         Chinqua    Michoacán
# 4                         Chinqua    Michoacán
# 5                  Sierra Chinqua    Michoacán
# 6                         Chinqua    Michoacán
# 7          Herrada or Las Palomas    Michoacán
# 8               El Rosario colony    Michoacán
# 9                         Chinqua    Michoacán
# 10                        Chinqua    Michoacán
# 11                Carrizo Springs           TX
# 12                    Rock Island           IL
# 13                        Waurika           OK
# 14                    Westbrook e           CT
# 15                  Arkansas City           KS
# 16                Wappinger Falls          NY:
# 17                    Roxboroug h           PA
# 18                      El Dorado           KS
# 19                          Lyons           KS
# 20                      Worcester           MA
# 21  Lower South .Hampton Township           PA
# 22   Bellevue State Park Bellevue           IA
# 23                      Manhattan           KS
# 24                         Canton           KS
# 25                   Minneapol is           MN
# 26                        Garland           TX
# 27                      Keansburg           NJ
# 28                         Topeka           KS
# 29                    Cape May Pt           NJ
# 30                       Cape May           NJ
# 31                       Cape May           NJ
# 32                       Lawrence           KS
# 33                          Ridge           MD
# 34                      Lewisburg           WV
# 35                  Mifflin- burg           PA
# 36                        Andover           KS
# 37                       St Cloud           MN
# 38                         Salina           KS
# 39                         Austin           TX
# 40                         Wamego           KS
# 41                 Clinton- ville           WI
# 42                        Wichita           KS
# 43                         Olathe           KS
# 44                         Wamego           KS
# 45                     Stillwater           MN
# 46                 Corpus Christi           TX
# 47                 Gaithers- burg           MD
# 48                         Austin           TX
# 49                        Oakdale           MN
# 50        20 miles W of Iowa City           IA
# 51                      Brookline           NH

# %% [markdown]
# ### Create new column Report Country & clean up

# %%
add_country = df['Where Recovered'].str.extract("(Mexico)", expand=True)
add_country.columns = ['Report Country']
add_country.loc[add_country['Report Country'] == 'Mexico', 'Report Country'] = 'MEXICO'
add_country.loc[add_country['Report Country'].isnull(), 'Report Country'] = 'USA'
add_country
# Out:
#    Report Country
# 0          MEXICO
# 1          MEXICO
# 2          MEXICO
# 3          MEXICO
# 4          MEXICO
# 5          MEXICO
# 6          MEXICO
# 7          MEXICO
# 8          MEXICO
# 9          MEXICO
# 10         MEXICO
# 11            USA
# 12            USA
# 13            USA
# 14            USA
# 15            USA
# 16            USA
# 17            USA
# 18            USA
# 19            USA
# 20            USA
# 21            USA
# 22            USA
# 23            USA
# 24            USA
# 25            USA
# 26            USA
# 27            USA
# 28            USA
# 29            USA
# 30            USA
# 31            USA
# 32            USA
# 33            USA
# 34            USA
# 35            USA
# 36            USA
# 37            USA
# 38            USA
# 39            USA
# 40            USA
# 41            USA
# 42            USA
# 43            USA
# 44            USA
# 45            USA
# 46            USA
# 47            USA
# 48            USA
# 49            USA
# 50            USA
# 51            USA

# %% [markdown]
# ### Create new table with unneeded columns dropped

# %%
df4 = pd.concat([df, df2, df3, add_country], axis=1)
df4.drop(['Where Tagged', 'Where Recovered', 'report_city', 'tag_city'], axis=1, inplace=True)
df5 = df4[['Tag No.','Tag State', 'Tag Date', 'Report State', 'Report Country', 'Report Date', 'Miles']]
new_table = df5.copy()
new_table
# Out:
#    Tag No. Tag State      Tag Date Report State Report Country  \
# 0   AU 646        NY        19-Sep    Michoacán         MEXICO
# 1   BW 003        MD        14-Sep    Michoacán         MEXICO
# 2   AN 008        MN         4-Sep    Michoacán         MEXICO
# 3   AG 802        IA           NaN    Michoacán         MEXICO
# 4   CU 878        KS        23-Sep    Michoacán         MEXICO
# 5   BP 359        KS        18-Sep    Michoacán         MEXICO
# 6   BP 652        KS        18-Sep    Michoacán         MEXICO
# 7   BO 299        KS         1-Oct    Michoacán         MEXICO
# 8   CM 355        AR        25-Sep    Michoacán         MEXICO
# 9   CJ 954        KS        24-Sep    Michoacán         MEXICO
# 10  AS 887        KS        23-Sep    Michoacán         MEXICO
# 11  AM 907        KS        27-Sep           TX            USA
# 12  BH 331        OH           NaN           IL            USA
# 13  AS 610        KS        20-Sep           OK            USA
# 14  AU 652        NY        29-Sep           CT            USA
# 15  CG 235        KS        18-Sep           KS            USA
# 16  AO 022        NH           NaN          NY:            USA
# 17  CM 577        PA        12-Oct           PA            USA
# 18  BO 125        KS        22-Sep           KS            USA
# 19  CK 683        KS        20-Sep           KS            USA
# 20  CB 809        MA        13-Oct           MA            USA
# 21  BW 716        NJ        23-Sep           PA            USA
# 22  AQ 178        IA         9-Sep           IA            USA
# 23  AS 039        KS         3-Sep           KS            USA
# 24  204 AD        KS        17-Sep           KS            USA
# 25  AF 384        MN           NaN           MN            USA
# 26   CP694        TX           NaN           TX            USA
# 27  CB 662        NJ           NaN           NJ            USA
# 28  BO 329        KS        23-Sep           KS            USA
# 29  BE 018        NJ        28-Sep           NJ            USA
# 30  AX 734        NJ        24-Sep           NJ            USA
# 31  BE 146        NJ        30-Sep           NJ            USA
# 32  AR 216        KS        26-Sep           KS            USA
# 33   BA402        MD        28-Sep           MD            USA
# 34  BR 711        WV        13-Sep           WV            USA
# 35  AB 902        PA         8-Sep           PA            USA
# 36  CJ 946        KS        24-Sep           KS            USA
# 37  AQ 103        MN           NaN           MN            USA
# 38  BN 789        KS        17-Sep           KS            USA
# 39  CH 262        TX        21-Sep           TX            USA
# 40  CW 347        KS        20-Sep           KS            USA
# 41  AQ 443        WI        14-Sep           WI            USA
# 42  AR 833        KS           NaN           KS            USA
# 43  CI 706        KS        24-Sep           KS            USA
# 44   CA512        KS         7-Sep           KS            USA
# 45  BD 004        MN         2-Oct           MN            USA
# 46  MJ 356        TX           NaN           TX            USA
# 47  CN 555        MD           NaN           MD            USA
# 48  CQ 903        TX  10 May\n1996           TX            USA
# 49  AK 132       NaN           NaN           MN            USA
# 50  393 KG       NaN           NaN           IA            USA
# 51  AU 742       NaN           NaN           NH            USA
#
#        Report Date   Miles
# 0           Feb-96  2580.0
# 1        Dec\n1995  2285.0
# 2            1-Mar  1990.0
# 3        Mar\n1996  1820.0
# 4           Mar-96  1555.0
# 5           24-Feb  1510.0
# 6        Mar\n1996  1510.0
# 7           15-Jan  1500.0
# 8           30-Dec  1445.0
# 9        Mar\n1996  1445.0
# 10       Mar\n1996  1440.0
# 11          19-Oct   694.0
# 12           3-Oct   465.0
# 13           4-Oct   290.0
# 14          12-Oct   215.0
# 15          29-Sep   162.0
# 16          22-Sep   152.0
# 17          27-Oct   115.0
# 18          23-Sep    78.0
# 19          25-Sep    46.0
# 20          22-Oct    27.0
# 21          24-Sep    26.0
# 22          16-Sep    17.0
# 23          18-Sep    15.0
# 24          27-Sep    14.0
# 25          19-Oct    11.0
# 26     7 May\n1996     8.0
# 27  before\n14 Oct     3.0
# 28          26-Sep     2.0
# 29           2-Oct     0.0
# 30           1-Oct     0.0
# 31           1-Oct     0.0
# 32             NaN     0.0
# 33           1-Oct     0.0
# 34           6-Sep     0.0
# 35           9-Sep     0.0
# 36          25-Sep     0.0
# 37          24-Sep     0.0
# 38          20-Sep     0.0
# 39          28-Sep     0.0
# 40          20-Sep     0.0
# 41          15-Sep     0.0
# 42          27-Sep     0.0
# 43          29-Sep     0.0
# 44           7-Sep     0.0
# 45          16-Oct     0.0
# 46          11-Oct     0.0
# 47          22-Oct     0.0
# 48     12May\n1996     0.0
# 49          15-Oct     NaN
# 50          18-Aug     NaN
# 51           3-Oct     NaN

# %% [markdown]
# ### Final check for unwanted spaces

# %%
# new_table.loc[new_table['Report State'].str.contains(r'\s', na=False), 'Report State'].value_counts()
# new_table.loc[new_table['Tag State'].str.contains(r'\s', na=False), 'Tag State'].value_counts()
# new_table.loc[new_table['Tag No.'].str.contains(r'\s', na=False), 'Tag No.'].value_counts()
# new_table.loc[new_table['Report Country'].str.contains(r'\s', na=False), 'Report Country'].value_counts()
# Out:
# Series([], Name: Report Country, dtype: int64)

# %% [markdown]
# ### Convert date columns to DateTime datatypes

# %%
new_table["Tag Date"]= pd.to_datetime(new_table["Tag Date"]) 
new_table["Report Date"]= pd.to_datetime(new_table["Report Date"]) 
new_table.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1978         try:
# -> 1979             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1980             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-104-17ada5706383> in <module>
# ----> 1 new_table["Tag Date"]= pd.to_datetime(new_table["Tag Date"])
#       2 new_table["Report Date"]= pd.to_datetime(new_table["Report Date"])
#       3 new_table.dtypes
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     776             result = arg.map(cache_array)
#     777         else:
# --> 778             values = convert_listlike(arg._values, True, format)
#     779             result = arg._constructor(values, index=arg.index, name=arg.name)
#     780     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     461             errors=errors,
#     462             require_iso8601=require_iso8601,
# --> 463             allow_object=True,
#     464         )
#     465
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1982             return values.view("i8"), tz_parsed
#    1983         except (ValueError, TypeError):
# -> 1984             raise e
#    1985
#    1986     if tz_parsed is not None:
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1973             dayfirst=dayfirst,
#    1974             yearfirst=yearfirst,
# -> 1975             require_iso8601=require_iso8601,
#    1976         )
#    1977     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1-09-19 00:00:00

# %%
del df2, df3, df4, df5, add_country

# %% [markdown]
# ### Export cleaned data to csv.

# %%
#new_table.to_csv("Monarchs1995.csv")
