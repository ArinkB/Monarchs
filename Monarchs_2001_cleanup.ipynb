# %%
import pandas as pd
import sqlite3
import os

# %%
db = sqlite3.connect("Monarchs2001.db")

# %%
df = pd.read_csv(r".\2001 Season Summary.csv")

        #convert pandas to SQL table
df.to_sql("monarchs2001", db, if_exists="replace")

os.getcwd
# Out:
# C:\Users\Arink\Anaconda3\lib\site-packages\pandas\core\generic.py:2712: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,
# <function nt.getcwd()>

# %%
schema = pd.read_sql('SELECT * FROM sqlite_master ORDER by name', db)
schema
# Out:
#     type                    name       tbl_name  rootpage  \
# 0  index   ix_monarchs2001_index   monarchs2001        63
# 1  index  ix_monarchs_2001_index  monarchs_2001         3
# 2  table            monarchs2001   monarchs2001        62
# 3  table           monarchs_2001  monarchs_2001         2
#
#                                                  sql
# 0  CREATE INDEX "ix_monarchs2001_index"ON "monarc...
# 1  CREATE INDEX "ix_monarchs_2001_index"ON "monar...
# 2  CREATE TABLE "monarchs2001" (\n"index" INTEGER...
# 3  CREATE TABLE "monarchs_2001" (\n"index" INTEGE...

# %% [markdown]
# ## Checking DataType

# %%
data_type = pd.read_sql('SELECT * FROM PRAGMA_TABLE_INFO("monarchs2001")', db)
data_type
# Out:
#    cid                   name     type  notnull dflt_value  pk
# 0    0                  index  INTEGER        0       None   0
# 1    1                Tag No.     TEXT        0       None   0
# 2    2                 Tagger     TEXT        0       None   0
# 3    3    Tag  Location, Date     TEXT        0       None   0
# 4    4  Report Date, Location     TEXT        0       None   0
# 5    5               Reporter     TEXT        0       None   0
# 6    6                  Miles     REAL        0       None   0

# %% [markdown]
# ### Drop tagger and reporter identification

# %%
df.drop(["Tagger", "Reporter"], axis = 1, inplace = True)
df
# Out:
#      Tag No.        Tag  Location, Date              Report Date, Location  \
# 0     AAD929     Salisbury, MA 09-12-01      02-11-02 El Rosario, MICH, MX
# 1     AAD844     Salisbury, MA 09-12-01  03-08-02 Sierra Chincua, MICH, MX
# 2     AIO261     Champlain, NY 09-24-01      03-13-02 El Rosario, MICH, MX
# 3     AAU820   Plattsburgh, NY 08-29-01      02-27-02 El Rosario, MICH, MX
# 4     ABG581  Saranac Lake, NY 09-16-01      03-13-02 El Rosario, MICH, MX
# ...      ...                        ...                                ...
# 1957  ADE225                        NaN             10-06-01 Lakeville, MN
# 1958  ABW153                        NaN  03-08-02 Sierra Chincua, MICH, MX
# 1959  AJA875                        NaN      02-26-02 El Rosario, MICH, MX
# 1960  ADR234                        NaN      02-26-02 El Rosario, MICH, MX
# 1961  AAG669                        NaN              09-16-01 Guilford, CT
#
#        Miles
# 0     2344.0
# 1     2343.0
# 2     2329.0
# 3     2315.0
# 4     2303.0
# ...      ...
# 1957     NaN
# 1958     NaN
# 1959     NaN
# 1960     NaN
# 1961     NaN
#
# [1962 rows x 4 columns]

# %% [markdown]
# ### Rename columns for clean-up

# %%
df.rename(columns={'Tag  Location, Date': 'tag_date', 'Report Date, Location': 'report_date'}, inplace=True)
df
# Out:
#      Tag No.                   tag_date                        report_date  \
# 0     AAD929     Salisbury, MA 09-12-01      02-11-02 El Rosario, MICH, MX
# 1     AAD844     Salisbury, MA 09-12-01  03-08-02 Sierra Chincua, MICH, MX
# 2     AIO261     Champlain, NY 09-24-01      03-13-02 El Rosario, MICH, MX
# 3     AAU820   Plattsburgh, NY 08-29-01      02-27-02 El Rosario, MICH, MX
# 4     ABG581  Saranac Lake, NY 09-16-01      03-13-02 El Rosario, MICH, MX
# ...      ...                        ...                                ...
# 1957  ADE225                        NaN             10-06-01 Lakeville, MN
# 1958  ABW153                        NaN  03-08-02 Sierra Chincua, MICH, MX
# 1959  AJA875                        NaN      02-26-02 El Rosario, MICH, MX
# 1960  ADR234                        NaN      02-26-02 El Rosario, MICH, MX
# 1961  AAG669                        NaN              09-16-01 Guilford, CT
#
#        Miles
# 0     2344.0
# 1     2343.0
# 2     2329.0
# 3     2315.0
# 4     2303.0
# ...      ...
# 1957     NaN
# 1958     NaN
# 1959     NaN
# 1960     NaN
# 1961     NaN
#
# [1962 rows x 4 columns]

# %% [markdown]
# ### Split & rename combined columns in Tagged category

# %%
df2 = df['tag_date'].str.split(', ', expand=True)
df3 = df2[1].str.split(' ', expand=True)
df2.columns = ['tag_city', 'state_date']
df3.columns = ['Tagged State', 'Tagged Date']
df3
# Out:
#      Tagged State Tagged Date
# 0              MA    09-12-01
# 1              MA    09-12-01
# 2              NY    09-24-01
# 3              NY    08-29-01
# 4              NY    09-16-01
# ...           ...         ...
# 1957          NaN         NaN
# 1958          NaN         NaN
# 1959          NaN         NaN
# 1960          NaN         NaN
# 1961          NaN         NaN
#
# [1962 rows x 2 columns]

# %% [markdown]
# ### Split & Rename combined columns in Reported category

# %%
df4 = df['report_date'].str.split(', ', expand=True)
df5 = df4[0].str.extract('(\d\d-\d\d-\d\d)', expand=True)
#df6 = df4[0].str.replace('(\d\d-\d\d-\d\d)', '') - to seperate date from city. decided not to use city
df4.columns = ['city_date', 'Reported State', 'Reported Country']
df5.columns = ['Reported Date']

# %% [markdown]
# ### Create new table with unneeded columns dropped

# %%
df7 = pd.concat([df, df2, df3, df4, df5], axis=1)
df7.drop(['state_date', 'tag_date', 'city_date', 'tag_city'], axis=1, inplace=True)
df8 = df7[['Tag No.','Tagged State', 'Tagged Date', 'Reported State', 'Reported Country', 'Reported Date', 'Miles']]
new_table = df8.copy()
new_table
# Out:
#      Tag No. Tagged State Tagged Date Reported State Reported Country  \
# 0     AAD929           MA    09-12-01           MICH               MX
# 1     AAD844           MA    09-12-01           MICH               MX
# 2     AIO261           NY    09-24-01           MICH               MX
# 3     AAU820           NY    08-29-01           MICH               MX
# 4     ABG581           NY    09-16-01           MICH               MX
# ...      ...          ...         ...            ...              ...
# 1957  ADE225          NaN         NaN             MN             None
# 1958  ABW153          NaN         NaN           MICH               MX
# 1959  AJA875          NaN         NaN           MICH               MX
# 1960  ADR234          NaN         NaN           MICH               MX
# 1961  AAG669          NaN         NaN             CT             None
#
#      Reported Date   Miles
# 0         02-11-02  2344.0
# 1         03-08-02  2343.0
# 2         03-13-02  2329.0
# 3         02-27-02  2315.0
# 4         03-13-02  2303.0
# ...            ...     ...
# 1957      10-06-01     NaN
# 1958      03-08-02     NaN
# 1959      02-26-02     NaN
# 1960      02-26-02     NaN
# 1961      09-16-01     NaN
#
# [1962 rows x 7 columns]

# %%
new_table["Tagged Date"]= pd.to_datetime(new_table["Tagged Date"]) 
new_table["Reported Date"]= pd.to_datetime(new_table["Reported Date"]) 
new_table.dtypes
# Out:
# Tag No.                     object
# Tagged State                object
# Tagged Date         datetime64[ns]
# Reported State              object
# Reported Country            object
# Reported Date       datetime64[ns]
# Miles                      float64
# dtype: object

# %% [markdown]
# ### Export cleaned data to csv.

# %%
new_table.to_csv("Monarchs2001.csv")
